# %% [markdown]
# <a href="https://colab.research.google.com/github/gitBgarn/COS3109/blob/main/COS3109_week3_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Github repository

# %% [markdown]
# https://github.com/VoLKyyyOG/TicTacToe-AI-agent.git

# %% [markdown]
# ##Check Github installation

# %%
# !git
# Out:
# usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#            [-p | --paginate | --no-pager] [--no-replace-objects] [--bare]
#            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#            <command> [<args>]
#
# These are common Git commands used in various situations:
#
# start a working area (see also: git help tutorial)
#    clone      Clone a repository into a new directory
#    init       Create an empty Git repository or reinitialize an existing one
#
# work on the current change (see also: git help everyday)
#    add        Add file contents to the index
#    mv         Move or rename a file, a directory, or a symlink
#    reset      Reset current HEAD to the specified state
#    rm         Remove files from the working tree and from the index
#
# examine the history and state (see also: git help revisions)
# ...

# %%
# !git --version
# Out:
# git version 2.17.1

# %% [markdown]
# ##Clone repository

# %%
# !git clone https://github.com/VoLKyyyOG/TicTacToe-AI-agent.git
# Out:
# Cloning into 'TicTacToe-AI-agent'...
# remote: Enumerating objects: 36, done.
# remote: Total 36 (delta 0), reused 0 (delta 0), pack-reused 36
# Unpacking objects: 100% (36/36), done.

# %% [markdown]
# ##Check working directory

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ##Mount my Gdrive

# %%
from google.colab import drive
ROOT = "/content/GDrive"
drive.mount(ROOT)
# Out:
# Drive already mounted at /content/GDrive; to attempt to forcibly remount, call drive.mount("/content/GDrive", force_remount=True).

# %%
#Create project path
project_Path = "/content/GDrive/MyDrive/3109/TicTacToeAgent"
# !mkdir = "{project_Path}"
# Out:
# mkdir: cannot create directory ‘=’: File exists

# %%
#Move files to the project directory
# !mv /content/TicTacToe-AI-agent* "{project_Path}"

# %%
# !rm -rf /content/TicTacToe-AI-agent

# %% [markdown]
# #Assignment

# %% [markdown]
# ![26971271-BE15-4851-AF65-B6D0A0BABF75.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Screenshot

# %% [markdown]
# ##Screenshot of GDrive

# %% [markdown]
# ##Screenshot of Github
